# %% [markdown]
# # TLDP Safe Sandbox (Google Colab)
#
# This notebook runs on **Google's computers**, not your laptop, so code you did not write cannot touch your files. It is the **completely free** option: you only need a Google account.
#
# **Rules that matter more than any tool:**
# 1. Public or **synthetic data only**.
# 2. **Never** paste a real password, API key, token, or `.env` value into a cell.
# 3. Treat this as **disposable**. When you finish: `Runtime -> Disconnect and delete runtime`.
# 4. A passed automated check is **not** proof code is safe. Read it before you run it.
#
# Copy this notebook to your own Drive first: `File -> Save a copy in Drive`.

# %% [markdown]
# ## 1. Confirm you are in the sandbox, not on your own machine

# %%
import sys, platform
IN_COLAB = 'google.colab' in sys.modules
print('Running in Colab sandbox:' , IN_COLAB)
print('Host:', platform.platform())
assert IN_COLAB, 'Stop: run this in Google Colab (colab.research.google.com), not on your laptop.'

# %% [markdown]
# ## 2. Fetch a repo to look at (change OWNER/REPO)

# %%
OWNER_REPO = 'OWNER/REPO'  # <- paste the repo you want to try, e.g. 'kernc/backtesting.py'
# !git clone --depth 1 https://github.com/{OWNER_REPO} project
# %cd project
# !ls -la

# %% [markdown]
# ## 3. READ before you run
#
# Open `README.md` and the main script below. Look for: downloads from odd sites, base64 blobs, `os.system`/`subprocess` calls, requests to unknown URLs, or 'disable your antivirus' style instructions. If anything looks off, **stop and report it** instead of running.

# %%
import pathlib
for f in sorted(pathlib.Path('.').rglob('*.py'))[:5]:
    print('=====', f)
    print(f.read_text(errors='replace')[:1500])

# %% [markdown]
# ## 4. Install deps and run — inside the sandbox only

# %%
# only after you've read the code and it looks legitimate
# !pip install -q -r requirements.txt || echo 'no requirements.txt'
# then run whatever the README says, e.g.:
# !python main.py

# %% [markdown]
# ## 5. Reset when done
#
# `Runtime -> Disconnect and delete runtime`. The sandbox and everything in it is destroyed. Nothing was ever on your laptop.
